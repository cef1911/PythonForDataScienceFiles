# %%
pwd
# Out:
# 'C:\\Users\\cef19\\Desktop\\DPhi'

# %%
import pandas as pd

# %%
S = [10, 'Bangalesh', 20.7, 'India']
print(type(S))
# Out:
# <class 'list'>

# %%
pd.Series(S)
# https://bootcamp.dphi.tech/introduction-to-pandas/module-2-series-and-dataframe/series
# Out:
# 0           10
# 1    Bangalesh
# 2         20.7
# 3        India
# dtype: object

# %%
import pandas as pd

# %%
exam_scores = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/exam_scores.csv") 
# the csv file 'exam_scores' is located in the current working directory

# %%
exam_scores.shape
# Out:
# (1000, 8)

# %%
exam_scores.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2    male        group C                some college  free/reduced
# 3  female        group D           bachelor's degree  free/reduced
# 4    male        group D                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          74             68             67
# 1               completed          58             68             66
# 2                    none          66             65             65
# 3                    none          74             75             73
# 4                    none          78             77             71

# %%
exam_scores.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
exam_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
exam_scores.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000     1000.00000    1000.000000
# mean     67.128000       70.17400      68.973000
# std      14.815367       14.85599      15.109155
# min      15.000000       18.00000      10.000000
# 25%      58.000000       60.00000      59.000000
# 50%      67.000000       70.00000      69.000000
# 75%      78.000000       81.00000      80.000000
# max     100.000000      100.00000     100.000000

# %%
SMAD = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv")

# %%
SMAD.shape
# Out:
# (99, 10)

# %%
SMAD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
SMAD.head()
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# 2       50.6      2066.3   33216       1       41.32
# 3       52.2      1966.7   32906       2       67.38
# 4       66.1      1514.5   26573       4       80.19

# %%
SMAD.dtypes
# Out:
# land_area           int64
# percent_city      float64
# percent_senior    float64
# physicians          int64
# hospital_beds       int64
# graduates         float64
# work_force        float64
# income              int64
# region              int64
# crime_rate        float64
# dtype: object

# %%
exam_scores.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2    male        group C                some college  free/reduced
# 3  female        group D           bachelor's degree  free/reduced
# 4    male        group D                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          74             68             67
# 1               completed          58             68             66
# 2                    none          66             65             65
# 3                    none          74             75             73
# 4                    none          78             77             71

# %%
exam_scores.iloc[0,0]
# Out:
# 'male'

# %%
exam_scores.iloc[0:5, 4]
# Out:
# 0         none
# 1    completed
# 2         none
# 3         none
# 4         none
# Name: test preparation course, dtype: object

# %%
exam_scores.iloc[:,:]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2      male        group C                some college  free/reduced
# 3    female        group D           bachelor's degree  free/reduced
# 4      male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group C            some high school      standard
# 996  female        group E                some college      standard
# 997  female        group E          associate's degree  free/reduced
# 998  female        group C                 high school      standard
# 999    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
exam_scores.iloc[[0,1,2,3], 2]
# exam_scores.loc[0:5, ['gender', 'lunch', 'math score']]
# exam_scores.iloc[[0,1,2,3], 2]
# Out:
# 0    bachelor's degree
# 1         some college
# 2         some college
# 3    bachelor's degree
# Name: parental level of education, dtype: object

# %%
exam_scores.iloc[-5:, 0:2]
# Out:
#      gender race/ethnicity
# 995  female        group C
# 996  female        group E
# 997  female        group E
# 998  female        group C
# 999    male        group C

# %% [markdown]
# ### Label Based Selection

# %%
# loc and iloc are conceptually similar. The difference is that iloc considers the default indexing while loc ignores the default indexing 
# loc is used for selecting data based on the data index value/name, not the numerical positions.  
# The syntax for loc is similar to iloc: df.loc[ ], df is a dataframe. 
exam_scores.loc[0, 'race/ethnicity']
# Out:
# 'group B'

# %%
exam_scores.loc[0:5, ['gender', 'lunch', 'math score']]
# Select first five entries for columns -gender, lunch, and math score
# Out:
#    gender         lunch  math score
# 0    male      standard          74
# 1  female      standard          58
# 2    male  free/reduced          66
# 3  female  free/reduced          74
# 4    male      standard          78
# 5  female      standard          75

# %%
exam_scores.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000     1000.00000    1000.000000
# mean     67.128000       70.17400      68.973000
# std      14.815367       14.85599      15.109155
# min      15.000000       18.00000      10.000000
# 25%      58.000000       60.00000      59.000000
# 50%      67.000000       70.00000      69.000000
# 75%      78.000000       81.00000      80.000000
# max     100.000000      100.00000     100.000000

# %%
exam_scores.describe(include = 'object')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       502            294                         226       649
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       654

# %%
exam_scores.describe(include = 'all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       502            294                         226       649
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course   math score  reading score  writing score
# count                     1000  1000.000000     1000.00000    1000.000000
# ...

# %%
exam_scores['math score'].describe()
# Out:
# count    1000.000000
# mean       67.128000
# std        14.815367
# min        15.000000
# 25%        58.000000
# 50%        67.000000
# 75%        78.000000
# max       100.000000
# Name: math score, dtype: float64

# %%
exam_scores.gender.describe() # returns all the unique values in the column 'gender'
# Out:
# count       1000
# unique         2
# top       female
# freq         502
# Name: gender, dtype: object

# %%
# To see all the unique values and the number of times they are occuring in the dataset, we have a method called value_counts().
exam_scores.gender.value_counts()
# Out:
# female    502
# male      498
# Name: gender, dtype: int64

# %%
# sma_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv")
sma_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv")

# %%
sma_data.head(11)
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# 5        2815          23.1             6.7        7340          16941
# 6        8360          46.3             8.2        4047          14347
# 7        6794          60.1             6.3        4562          14333
# 8        3049          19.5            12.1        4005          21149
# 9        4647          31.5             9.2        3916          12815
# 10       1008          16.6            10.3        4006          16704
#
#     graduates  work_force  income  region  crime_rate
# 0        50.1      4083.9   72100       1       75.55
# ...

# %%
sma_data.loc[[]], [[]]
# Out:
# (Empty DataFrame
#  Columns: [land_area, percent_city, percent_senior, physicians, hospital_beds, graduates, work_force, income, region, crime_rate]
#  Index: [],
#  [[]])

# %%
sma_data.iloc[10,9]
# Out:
# 54.16

# %%
sma_data.tail()
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# 94       50.4       127.2    1452       4       70.66
# 95       30.3        80.6     769       3       36.36
# 96       70.7        93.2    1337       3       60.16
# 97       58.0        97.0    1589       1       36.33
# 98       55.1        66.9    1148       3       68.76

# %%
sma_data.iloc[98,3]
# Out:
# 140

# %%
sma_data.iloc[[1,3,5,7,9,13]], [['land_area','work_force', 'income', 'region', 'crime_rate']]
sample_data1 = sma_data.iloc[[1,3,5,7,9,13]], [['land_area','work_force', 'income', 'region', 'crime_rate']]
#sma_data.loc[[1]], [['percent_city']]
# exam_scores.iloc[[0,1,2,3], 2]
# 'land_area', 'work_force', 'income', 'region' and 'crime_rate'.

# %%
sample_data1
# Out:
# (    land_area  percent_city  percent_senior  physicians  hospital_beds  \
#  1        3719          43.9             9.4       13326          43292
#  3        3916          29.9             8.8        6402          24167
#  5        2815          23.1             6.7        7340          16941
#  7        6794          60.1             6.3        4562          14333
#  9        4647          31.5             9.2        3916          12815
#  13        782          28.4             7.8        3119           8656
#
#      graduates  work_force  income  region  crime_rate
#  1        53.9      3305.9   54542       2       56.03
#  3        52.2      1966.7   32906       2       67.38
#  5        68.3      1541.9   25663       3       58.48
#  7        51.7      1272.7   18221       3       64.88
#  9        65.1      1032.2   14542       2       55.30
#  13       70.5       915.2   12591       4       63.20  ,
#  [['land_area', 'work_force', 'income', 'region', 'crime_rate']])

# %%
sma_data.iloc[0,:]
# Out:
# land_area          1384.00
# percent_city         78.10
# percent_senior       12.30
# physicians        25627.00
# hospital_beds     69678.00
# graduates            50.10
# work_force         4083.90
# income            72100.00
# region                1.00
# crime_rate           75.55
# Name: 0, dtype: float64

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(sma_data)
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# 5        2815          23.1             6.7        7340          16941
# 6        8360          46.3             8.2        4047          14347
# 7        6794          60.1             6.3        4562          14333
# 8        3049          19.5            12.1        4005          21149
# 9        4647          31.5             9.2        3916          12815
# 10       1008          16.6            10.3        4006          16704
# 11       1519          31.8            10.5        4094          12545
# ...

# %%
select_region = sma_data.loc[sma_data['region'] == 2]
print(select_region)
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 1        3719          43.9             9.4       13326          43292
# 3        3916          29.9             8.8        6402          24167
# 9        4647          31.5             9.2        3916          12815
# 11       1519          31.8            10.5        4094          12545
# 15       1456          46.7            10.4        2484           8555
# 17       2149          29.8            10.6        2530           8354
# 19       3341          35.8            10.1        2289           7593
# 21       3072          68.0             9.3        2181           7497
# 23       2460          49.6             8.4        1874           7706
# 29       2187          47.0            10.2        1098           4342
# 35        903          37.3             9.6         948           4064
# 37        938          48.1             7.4         614           3016
# ...

# %%
exam_scores.describe(include = 'object')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       502            294                         226       649
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       654

# %%
exam_scores.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000     1000.00000    1000.000000
# mean     67.128000       70.17400      68.973000
# std      14.815367       14.85599      15.109155
# min      15.000000       18.00000      10.000000
# 25%      58.000000       60.00000      59.000000
# 50%      67.000000       70.00000      69.000000
# 75%      78.000000       81.00000      80.000000
# max     100.000000      100.00000     100.000000

# %%
exam_scores
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2      male        group C                some college  free/reduced
# 3    female        group D           bachelor's degree  free/reduced
# 4      male        group D                some college      standard
# 5    female        group D          associate's degree      standard
# 6    female        group B          associate's degree  free/reduced
# 7      male        group E            some high school  free/reduced
# 8      male        group C            some high school      standard
# 9      male        group B             master's degree      standard
# 10   female        group E                some college  free/reduced
# 11     male        group C           bachelor's degree      standard
# 12   female        group C                some college      standard
# ...

# %%
exam_scores.describe(include = 'all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       502            294                         226       649
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course   math score  reading score  writing score
# count                     1000  1000.000000     1000.00000    1000.000000
# ...

# %%
exam_scores['math score'].describe()
# Out:
# count    1000.000000
# mean       67.128000
# std        14.815367
# min        15.000000
# 25%        58.000000
# 50%        67.000000
# 75%        78.000000
# max       100.000000
# Name: math score, dtype: float64

# %%
exam_scores['gender'].describe()
# Out:
# count       1000
# unique         2
# top       female
# freq         502
# Name: gender, dtype: object

# %%
exam_scores.gender.describe()
# Out:
# count       1000
# unique         2
# top       female
# freq         502
# Name: gender, dtype: object

# %%
exam_scores['race/ethnicity'].describe()
# Out:
# count        1000
# unique          5
# top       group C
# freq          294
# Name: race/ethnicity, dtype: object

# %%
exam_scores.mean() # only numerical columns
# Out:
# math score       67.128
# reading score    70.174
# writing score    68.973
# dtype: float64

# %%
exam_scores.gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
exam_scores.gender.value_counts()
# Out:
# female    502
# male      498
# Name: gender, dtype: int64

# %% [markdown]
# ### Module 5 quiz info

# %%
sma_data.head(11)
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# 5        2815          23.1             6.7        7340          16941
# 6        8360          46.3             8.2        4047          14347
# 7        6794          60.1             6.3        4562          14333
# 8        3049          19.5            12.1        4005          21149
# 9        4647          31.5             9.2        3916          12815
# 10       1008          16.6            10.3        4006          16704
#
#     graduates  work_force  income  region  crime_rate
# 0        50.1      4083.9   72100       1       75.55
# ...

# %%
print(sma_data.mean())
# Out:
# land_area         2615.727273
# percent_city        42.518182
# percent_senior       9.781818
# physicians        1828.333333
# hospital_beds     6345.868687
# graduates           54.463636
# work_force         449.366667
# income            6762.505051
# region               2.494949
# crime_rate          55.643030
# dtype: float64

# %%
# exam_scores.gender.unique()
sma_data.region.unique()
# Out:
# array([1, 2, 4, 3], dtype=int64)

# %%
sma_data.region.value_counts()
# Out:
# 3    36
# 2    25
# 1    21
# 4    17
# Name: region, dtype: int64

# %%
sma_data.describe()
# Out:
#           land_area  percent_city  percent_senior    physicians  \
# count     99.000000     99.000000       99.000000     99.000000
# mean    2615.727273     42.518182        9.781818   1828.333333
# std     3045.826210     17.348277        2.524547   3192.199763
# min       47.000000     13.400000        3.900000    140.000000
# 25%     1408.000000     30.100000        8.350000    459.000000
# 50%     1951.000000     39.500000        9.700000    774.000000
# 75%     2890.500000     52.600000       10.750000   1911.500000
# max    27293.000000    100.000000       21.800000  25627.000000
#
#        hospital_beds  graduates   work_force        income     region  \
# count      99.000000  99.000000    99.000000     99.000000  99.000000
# mean     6345.868687  54.463636   449.366667   6762.505051   2.494949
# std      9136.202716   7.773286   610.990885  10393.349660   1.013921
# min       481.000000  30.300000    66.900000    769.000000   1.000000
# ...

# %%
sma_data.describe()
# Out:
#           land_area  percent_city  percent_senior    physicians  \
# count     99.000000     99.000000       99.000000     99.000000
# mean    2615.727273     42.518182        9.781818   1828.333333
# std     3045.826210     17.348277        2.524547   3192.199763
# min       47.000000     13.400000        3.900000    140.000000
# 25%     1408.000000     30.100000        8.350000    459.000000
# 50%     1951.000000     39.500000        9.700000    774.000000
# 75%     2890.500000     52.600000       10.750000   1911.500000
# max    27293.000000    100.000000       21.800000  25627.000000
#
#        hospital_beds  graduates   work_force        income     region  \
# count      99.000000  99.000000    99.000000     99.000000  99.000000
# mean     6345.868687  54.463636   449.366667   6762.505051   2.494949
# std      9136.202716   7.773286   610.990885  10393.349660   1.013921
# min       481.000000  30.300000    66.900000    769.000000   1.000000
# ...

# %%
sma_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
sample_data1 = sma_data.loc[sma_data['region'] == 3]
print(sample_data1)
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 5        2815          23.1             6.7        7340          16941
# 6        8360          46.3             8.2        4047          14347
# 7        6794          60.1             6.3        4562          14333
# 12       4326          23.6             7.3        3064           9976
# 16       2045          37.2            21.4        1949           8863
# 22       1967          51.1             8.8        2520           8467
# 26       1392          37.2             9.8        1579           6087
# 27       3358          35.1            11.3        1649           5512
# 30       3214          47.7             9.4        1285           3459
# 31       3491          48.5             9.7        1496           5620
# 32       4080          59.6             9.9        1597           7496
# 34       3199          80.6             8.7         983           4749
# ...

# %%
sma_data.region.value_counts()
# Out:
# 3    36
# 2    25
# 1    21
# 4    17
# Name: region, dtype: int64

# %%
exam_scores.sort_values(by = 'math score', ascending = False).head()
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 91    male        group D          associate's degree  standard
# 776   male        group E          associate's degree  standard
# 588   male        group D                some college  standard
# 128   male        group A          associate's degree  standard
# 565   male        group E           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 91                     none         100             94             96
# 776               completed         100            100            100
# 588               completed         100             85             91
# 128               completed         100             97             94
# 565               completed         100            100            100

# %%
exam_scores['math score'].sort_values(ascending = False)[:5]
# Out:
# 495    100
# 91     100
# 128    100
# 911    100
# 565    100
# Name: math score, dtype: int64

# %%
exam_scores.sort_values(by = 'math score').head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 949    male        group C                 high school  free/reduced
# 854    male        group C                 high school  free/reduced
# 891  female        group C                 high school  free/reduced
# 349    male        group B            some high school  free/reduced
# 739  female        group E            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 949                    none          15             18             10
# 854                    none          18             30             18
# 891                    none          23             31             27
# 349                    none          25             31             30
# 739                    none          25             35             38

# %%
exam_scores['math score'].sort_values()[:5]
# Out:
# 949    15
# 854    18
# 891    23
# 349    25
# 739    25
# Name: math score, dtype: int64

# %%
exam_scores.rename(columns = {'race/ethnicity':'race',
                              'parental level of education': 'parent_education_level',
                              'test preparation course': 'test_prep_course',
                              'math score': 'math_score',
                              'reading score': 'reading_score',
                              'writing score': 'writing_score'}, inplace = True)

# inplace =True will make these changes in the dataframe 'exam_scores' only

# %%
exam_scores.columns
# Out:
# Index(['gender', 'race', 'parent_education_level', 'lunch', 'test_prep_course',
#        'math_score', 'reading_score', 'writing_score'],
#       dtype='object')

# %%
exam_scores.head()
# Out:
#    gender     race parent_education_level         lunch test_prep_course  \
# 0    male  group B      bachelor's degree      standard             none
# 1  female  group C           some college      standard        completed
# 2    male  group C           some college  free/reduced             none
# 3  female  group D      bachelor's degree  free/reduced             none
# 4    male  group D           some college      standard             none
#
#    math_score  reading_score  writing_score
# 0          74             68             67
# 1          58             68             66
# 2          66             65             65
# 3          74             75             73
# 4          78             77             71

# %%
exam_scores.rename(index = {0 : 'zero', 1 : 'one', 3: 'three'}).head()

# We are not making the changes here in the orginal dataframe, so didn't pass inplace = True
# By default the 'inplace' parameter is set to False.
# Out:
#        gender     race parent_education_level         lunch test_prep_course  \
# zero     male  group B      bachelor's degree      standard             none
# one    female  group C           some college      standard        completed
# 2        male  group C           some college  free/reduced             none
# three  female  group D      bachelor's degree  free/reduced             none
# 4        male  group D           some college      standard             none
#
#        math_score  reading_score  writing_score
# zero           74             68             67
# one            58             68             66
# 2              66             65             65
# three          74             75             73
# 4              78             77             71

# %%
exam_scores
# Out:
#      gender     race parent_education_level         lunch test_prep_course  \
# 0      male  group B      bachelor's degree      standard             none
# 1    female  group C           some college      standard        completed
# 2      male  group C           some college  free/reduced             none
# 3    female  group D      bachelor's degree  free/reduced             none
# 4      male  group D           some college      standard             none
# 5    female  group D     associate's degree      standard        completed
# 6    female  group B     associate's degree  free/reduced             none
# 7      male  group E       some high school  free/reduced             none
# 8      male  group C       some high school      standard        completed
# 9      male  group B        master's degree      standard             none
# 10   female  group E           some college  free/reduced             none
# ...

# %%
sma_data
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# 5        2815          23.1             6.7        7340          16941
# 6        8360          46.3             8.2        4047          14347
# 7        6794          60.1             6.3        4562          14333
# 8        3049          19.5            12.1        4005          21149
# 9        4647          31.5             9.2        3916          12815
# 10       1008          16.6            10.3        4006          16704
# 11       1519          31.8            10.5        4094          12545
# ...

# %%
sorted_data1=sma_data.sort_values(by = 'crime_rate', ascending = False).head()

# %%
sorted_data1
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 20       9155          53.8            11.1        2280           6450
# 74       1412          39.2            11.3         436           1837
# 53       5966          39.5             9.6         737           1907
# 4        2480          31.5            10.5        8502          16751
# 67       8152          22.3             9.1         405           1254
#
#     graduates  work_force  income  region  crime_rate
# 20       60.1       575.2    7766       4       85.62
# 74       49.4       154.2    2098       4       82.68
# 53       52.7       246.6    3007       4       80.94
# 4        66.1      1514.5   26573       4       80.19
# 67       51.7       165.6    2257       4       78.10

# %%
sma_data.isna()
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       False         False           False       False          False
# 1       False         False           False       False          False
# 2       False         False           False       False          False
# 3       False         False           False       False          False
# 4       False         False           False       False          False
# 5       False         False           False       False          False
# 6       False         False           False       False          False
# 7       False         False           False       False          False
# 8       False         False           False       False          False
# 9       False         False           False       False          False
# 10      False         False           False       False          False
# 11      False         False           False       False          False
# ...

# %%
sma_data.isnull()
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       False         False           False       False          False
# 1       False         False           False       False          False
# 2       False         False           False       False          False
# 3       False         False           False       False          False
# 4       False         False           False       False          False
# 5       False         False           False       False          False
# 6       False         False           False       False          False
# 7       False         False           False       False          False
# 8       False         False           False       False          False
# 9       False         False           False       False          False
# 10      False         False           False       False          False
# 11      False         False           False       False          False
# ...

# %%
exam_scores.isnull()
# Out:
#      gender   race  parent_education_level  lunch  test_prep_course  \
# 0     False  False                   False  False             False
# 1     False  False                   False  False             False
# 2     False  False                   False  False             False
# 3     False  False                   False  False             False
# 4     False  False                   False  False             False
# 5     False  False                   False  False             False
# 6     False  False                   False  False             False
# 7     False  False                   False  False             False
# 8     False  False                   False  False             False
# 9     False  False                   False  False             False
# 10    False  False                   False  False             False
# 11    False  False                   False  False             False
# 12    False  False                   False  False             False
# ...

# %%
exam_scores.isna()
# Out:
#      gender   race  parent_education_level  lunch  test_prep_course  \
# 0     False  False                   False  False             False
# 1     False  False                   False  False             False
# 2     False  False                   False  False             False
# 3     False  False                   False  False             False
# 4     False  False                   False  False             False
# 5     False  False                   False  False             False
# 6     False  False                   False  False             False
# 7     False  False                   False  False             False
# 8     False  False                   False  False             False
# 9     False  False                   False  False             False
# 10    False  False                   False  False             False
# 11    False  False                   False  False             False
# 12    False  False                   False  False             False
# ...

# %%
exam_scores.isna().sum()
# Out:
# gender                    0
# race                      0
# parent_education_level    0
# lunch                     0
# test_prep_course          0
# math_score                0
# reading_score             0
# writing_score             0
# dtype: int64

# %%
exam_scores.isnull().sum()
# Out:
# gender                    0
# race                      0
# parent_education_level    0
# lunch                     0
# test_prep_course          0
# math_score                0
# reading_score             0
# writing_score             0
# dtype: int64

# %%
sma_data.isnull().sum()
# Out:
# land_area         0
# percent_city      0
# percent_senior    0
# physicians        0
# hospital_beds     0
# graduates         0
# work_force        0
# income            0
# region            0
# crime_rate        0
# dtype: int64

# %%
sma_data.isna().sum()
# Out:
# land_area         0
# percent_city      0
# percent_senior    0
# physicians        0
# hospital_beds     0
# graduates         0
# work_force        0
# income            0
# region            0
# crime_rate        0
# dtype: int64

# %%
sma_data['land_area'].mean()
# Out:
# 2615.7272727272725

# %%
sma_data['land_area'].fillna(sma_data['land_area'].mean(), inplace = True)

# filling the missing value in land_area column

# %%
sma_data
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# 5        2815          23.1             6.7        7340          16941
# 6        8360          46.3             8.2        4047          14347
# 7        6794          60.1             6.3        4562          14333
# 8        3049          19.5            12.1        4005          21149
# 9        4647          31.5             9.2        3916          12815
# 10       1008          16.6            10.3        4006          16704
# 11       1519          31.8            10.5        4094          12545
# ...

# %%
import pandas as pd
ckd_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Chronic%20Kidney%20Disease%20(CKD)%20Dataset/ChronicKidneyDisease.csv")

# %%
ckd_data.head(10)
# Out:
#    id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0   0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1   1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2   2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3   3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4   4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5   5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6   6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7   7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8   8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9   9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
#
#            ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# 0  notpresent  ...   44   7800  5.2  yes  yes   no  good   no   no
# 1  notpresent  ...   38   6000  NaN   no   no   no  good   no   no
# ...

# %%
ckd_data.tail(7)
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 393  393  43.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 394  394  50.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn  dm  cad appet  pe ane classification
# 393  ...   54  7400  5.4   no  no   no  good  no  no         notckd
# 394  ...   45  9500  4.6   no  no   no  good  no  no         notckd
# 395  ...   47  6700  4.9   no  no   no  good  no  no         notckd
# 396  ...   54  7800  6.2   no  no   no  good  no  no         notckd
# ...

# %%
ckd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
ckd_data.describe(include='all')
# Out:
#                 id         age          bp          sg          al  \
# count   400.000000  391.000000  388.000000  353.000000  354.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean    199.500000   51.483376   76.469072    1.017408    1.016949
# std     115.614301   17.169714   13.683637    0.005717    1.352679
# min       0.000000    2.000000   50.000000    1.005000    0.000000
# 25%      99.750000   42.000000   70.000000    1.010000    0.000000
# 50%     199.500000   55.000000   80.000000    1.020000    0.000000
# 75%     299.250000   64.500000   80.000000    1.020000    2.000000
# max     399.000000   90.000000  180.000000    1.025000    5.000000
#
#                 su     rbc      pc         pcc          ba  ...  pcv    wc  \
# count   351.000000     248     335         396         396  ...  330   295
# ...

# %%
ckd_data.loc[247:253, ["id", "age", "classification"]]
# Out:
#       id   age classification
# 247  247  54.0            ckd
# 248  248  59.0            ckd
# 249  249  56.0            ckd
# 250  250  40.0         notckd
# 251  251  23.0         notckd
# 252  252  45.0         notckd
# 253  253  57.0         notckd

# %%
ckd_data.rename(columns = {
   "id": "Id",
   "age": "Age",
   "bp": "blood_pressure",
}, inplace=True)

# %%
ckd_data
# Out:
#       Id   Age  blood_pressure     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0            80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0            50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0            80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0            70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0            80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...             ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0            80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0            70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0            80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0            60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0            80.0  1.025  0.0  0.0  normal    normal  notpresent
#
# ...

# %%
ckd_data.isna()
# Out:
#         Id    Age  blood_pressure     sg     al     su    rbc     pc    pcc  \
# 0    False  False           False  False  False  False   True  False  False
# 1    False  False           False  False  False  False   True  False  False
# 2    False  False           False  False  False  False  False  False  False
# 3    False  False           False  False  False  False  False  False  False
# 4    False  False           False  False  False  False  False  False  False
# ..     ...    ...             ...    ...    ...    ...    ...    ...    ...
# 395  False  False           False  False  False  False  False  False  False
# 396  False  False           False  False  False  False  False  False  False
# 397  False  False           False  False  False  False  False  False  False
# 398  False  False           False  False  False  False  False  False  False
# 399  False  False           False  False  False  False  False  False  False
#
# ...

# %%
ckd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              400 non-null    int64
#  1   Age             391 non-null    float64
#  2   blood_pressure  388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
ckd_data.mean()
# Out:
# Id                199.500000
# Age                51.483376
# blood_pressure     76.469072
# sg                  1.017408
# al                  1.016949
# su                  0.450142
# bgr               148.036517
# bu                 57.425722
# sc                  3.072454
# sod               137.528754
# pot                 4.627244
# hemo               12.526437
# dtype: float64

# %%
ckd_data['blood_pressure'].fillna(ckd_data['blood_pressure'].mean(), inplace = True)

# %%
ckd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              400 non-null    int64
#  1   Age             391 non-null    float64
#  2   blood_pressure  400 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
ckd_data.describe(include='all')
# Out:
#                 Id         Age  blood_pressure          sg          al  \
# count   400.000000  391.000000      400.000000  353.000000  354.000000
# unique         NaN         NaN             NaN         NaN         NaN
# top            NaN         NaN             NaN         NaN         NaN
# freq           NaN         NaN             NaN         NaN         NaN
# mean    199.500000   51.483376       76.469072    1.017408    1.016949
# std     115.614301   17.169714       13.476298    0.005717    1.352679
# min       0.000000    2.000000       50.000000    1.005000    0.000000
# 25%      99.750000   42.000000       70.000000    1.010000    0.000000
# 50%     199.500000   55.000000       78.234536    1.020000    0.000000
# 75%     299.250000   64.500000       80.000000    1.020000    2.000000
# max     399.000000   90.000000      180.000000    1.025000    5.000000
#
#                 su     rbc      pc         pcc          ba  ...  pcv    wc  \
# ...

# %%
ckd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              400 non-null    int64
#  1   Age             391 non-null    float64
#  2   blood_pressure  400 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
ckd_data['cad'].fillna(ckd_data['cad'].mean(), inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-73eaaf07ea22> in <module>
# ----> 1 ckd_data['cad'].fillna(ckd_data['cad'].mean(), inplace = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
# ...

# %%
ckd_data.to_csv("test.csv")

# %%
pwd
# Out:
# 'C:\\Users\\cef19\\Desktop\\DPhi'

# %%
a = pd.read_csv("C:\\Users\\cef19\\Desktop\\DPhi\\test.csv")

# %%
a
# Out:
#      Unnamed: 0   Id   Age  blood_pressure     sg   al   su     rbc        pc  \
# 0             0    0  48.0            80.0  1.020  1.0  0.0     NaN    normal
# 1             1    1   7.0            50.0  1.020  4.0  0.0     NaN    normal
# 2             2    2  62.0            80.0  1.010  2.0  3.0  normal    normal
# 3             3    3  48.0            70.0  1.005  4.0  0.0  normal  abnormal
# 4             4    4  51.0            80.0  1.010  2.0  0.0  normal    normal
# ..          ...  ...   ...             ...    ...  ...  ...     ...       ...
# 395         395  395  55.0            80.0  1.020  0.0  0.0  normal    normal
# 396         396  396  42.0            70.0  1.025  0.0  0.0  normal    normal
# 397         397  397  12.0            80.0  1.020  0.0  0.0  normal    normal
# 398         398  398  17.0            60.0  1.025  0.0  0.0  normal    normal
# 399         399  399  58.0            80.0  1.025  0.0  0.0  normal    normal
#
# ...
